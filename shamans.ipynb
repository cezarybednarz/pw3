# %%
import matplotlib.pyplot as plt
import numpy as np


sort10000 = np.genfromtxt('src/tests/sort1000.csv', delimiter=',')

proc = np.array([0, 1, 2, 3, 4, 8, 16, 32, 48])

plt.plot(proc, sort10000[0])
plt.plot(proc, sort10000[1])
plt.plot(proc, sort10000[2])
plt.plot(proc, sort10000[3])
